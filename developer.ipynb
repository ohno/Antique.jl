# %% [markdown]
# # Antiq.jl

# %% [markdown]
# ## PkgTemplates.jl
#
# https://qiita.com/SatoshiTerasaki/items/7dbb809c962e794a9df6
#
# ```julia
# # using Pkg
# # Pkg.add("PkgTemplates")
# using PkgTemplates
#
# t = Template(;
#     user="ohno",
#     authors = ["Shuhei Ohno"]
#     dir = pwd(),
#     julia=v"1",
#     plugins = [
#         License(; name = "MIT"),
#         ProjectFile(; version=v"0.0.1"),
#         Git(; manifest = false, ssh = true),
#         GitHubActions(;
#             extra_versions = ["1.6", "1.7", "nightly"]
#         ),
#         Documenter{GitHubActions}(),
#         Readme(;
#             inline_badges = true,
#             badge_order = DataType[
#                 GitHubActions,
#                 Documenter{GitHubActions},
#             ],
#         ),
#     ],
# )
#
# generate("Antiq.jl", t)
# ```

# %% [markdown]
# ## using Antiq
#
# Please move `./develop.ipynb` into `./Antig.jl/` before run following.

# %%
versioninfo()

using Pkg
# Pkg.add("Weave")
# Pkg.add("Revise")
# using Weave
using Revise

Pkg.activate("./")
# Pkg.resolve()
using Antiq
# Out:
# Julia Version 1.8.3
# Commit 0434deb161 (2022-11-14 20:14 UTC)
# Platform Info:
#   OS: Windows (x86_64-w64-mingw32)
#   CPU: 8 × 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, tigerlake)
#   Threads: 1 on 8 virtual cores
#   Activating project at `C:\Users\user\Desktop\GitHub\Antiq.jl`

# %% [markdown]
# ## Logo
#
# - https://github.com/JuliaLang/julia-logo-graphics
# - https://products.aspose.app/imaging/conversion/svg-to-ico

# %%
function XY2path(X,Y)
    X = 252 / (maximum(X) - minimum(X)) * (X .- minimum(X)) .+ 50
    Y = 260 .- 445  .*  Y
    path = "M$(X[1]),$(Y[1]) "
    for i in 2:length(X)
        path *= "L$(X[i]),$(Y[i]) "
    end
    return path
end

HA = antiq(:HydrogenAtom, Z=1, Eₕ=1.0, a₀=1.0, mₑ=1.0, ℏ=1.0)
paths = Dict()
X = 0.0:0.01:8
Y1 = X .^2 .* HA.R.(X,n=1) .^2
Y2 = X .^2 .* HA.R.(X,n=2,l=0) .^2
Y3 = X .^2 .* HA.R.(X,n=2,l=1) .^2
Y4 = X .^2 .* HA.R.(X,n=3,l=0) .^2
paths[1] = XY2path(X,Y1)
paths[2] = XY2path(X,Y2)
paths[3] = XY2path(X,Y3)
paths[4] = XY2path(X,Y4)

colors = ["#4063D8", "#CB3C33", "#389826", "#9558B2"]

as = 4
lw = 9

svg = """
<?xml version="1.0" encoding="UTF-8"?>
<svg
  version="1.1"
  xmlns="http://www.w3.org/2000/svg"
  xmlns:xlink="http://www.w3.org/1999/xlink"
  width="325pt"
  height="300pt"
  viewBox="0 0 325 300"
>

  <!-- Defs -->
  <defs>
    <marker id="arrow" markerWidth="$(as)" markerHeight="$(as)" refX="0" refY="$(as/2)" orient="auto">
      <polygon points="0,0 0,$(as) $(as),$(as/2)" fill="#24292E"/>
    </marker>
  </defs>

  <!-- Body --> 
  <path d="$(paths[4])" fill="none" stroke="$(colors[4])" stroke-width="$(lw)" stroke-linecap="round" />
  <path d="$(paths[3])" fill="none" stroke="$(colors[3])" stroke-width="$(lw)" stroke-linecap="round" />
  <path d="$(paths[2])" fill="none" stroke="$(colors[2])" stroke-width="$(lw)" stroke-linecap="round" />
  <path d="$(paths[1])" fill="none" stroke="$(colors[1])" stroke-width="$(lw)" stroke-linecap="round" />
  <path d="M10,260 L285,260," stroke="#24292E" stroke-width="$(lw)" stroke-linecap="round"  marker-end="url(#arrow)"/>
  <path d="M40,290 L40,40" stroke="#24292E" stroke-width="$(lw)" stroke-linecap="round"  marker-end="url(#arrow)"/>

</svg>
"""

HTML(svg) |> display

path = "./docs/src/assets/logo.svg"
mkpath(dirname(path))
file = open(path, "w")
Base.write(file, svg)
close(file)
# Out:
# HTML{String}("<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n<svg\n  version=\"1.1\"\n  xmlns=\"http://www.w3.org/2000/svg\"\n  xmlns:xlink=\"http://www.w3.org/1999/xlink\"\n  width=\"325pt\"\n  height=\"300pt\"\n  viewBox=\"0 0 325 300\"\n>\n\n  <!-- Defs -->\n  <defs>\n    <marker id=\"arrow\" markerWidth=\"4\" markerHeight=\"4\" refX=\"0\" refY=\"2.0\" orient=\"auto\">\n      <polygon points=\"0,0 0,4 4,2.0\" fill=\"#24292E\"/>\n    </marker>\n  </defs>\n\n  <!-- Body --> \n  <path d=\"M50.0,260.0 L50.315,259.9935381415931 L50.63,259.9746666494666 L50.945,259.9441370205567 L51.26,259.90267509557646 L51.575,259.85098169100775 L51.89,259.78973321859246 L52.205,259.71958229253386 L52.52,259.6411583246156 L52.835,259.55506810744356 L53.15,259.4618963860121 L53.465,259.362206417793 L53.78,259.25654052154323 L54.095,259.1454206150242 L54.41,259.0293487418217 L54.725,258.90880758745425 L55.04,258.7842609849534 L55.355,258.65615441009754 L55.67,258.5249154664775 L55.985,258.3909543605703 L56.3,258.25466436699327 L56.615,258.1164222841103 L56.93,257.97658888015707 L57.245,257.83550933005085 L57.56,257.6935136430484 L57.875,257.55091708141066 L58.19,257.40802057023456 L58.505,257.26511109860434 L58.82,257.1224621122182 L59.135,256.980333897639 L59.45,256.8389739583185 L59.765,256.69861738254014 L60.08,256.55948720342565 L60.395,256.4217947511451 L60.71,256.2857399974714 L61.025,256.1515118928156 L61.34,256.01928869587795 L61.655,255.88923829604806 L61.97,255.76151852868495 L62.285,255.63627748340525 L62.6,255.513653805507 L62.915,255.39377699065327 L63.23,255.27676767293897 L63.545,255.16273790646113 L63.86,255.05179144051203 L64.175,254.94402398851204 L64.49,254.8395234907976 L64.805,254.73837037137744 L65.12,254.6406377887689 L65.435,254.5463918810241 L65.75,254.45569200505378 L66.065,254.36859097035554 L66.38,254.28513526725087 L66.695,254.20536528973378 L67.01,254.1293155530328 L67.325,254.05701490598543 L67.64,253.98848673832353 L67.955,253.92374918296602 L68.27,253.86281531341356 L68.585,253.80569333633906 L68.9,253.75238677946535 L69.215,253.70289467482078 L69.53,253.65721173746144 L69.845,253.61532853974737 L70.16,253.5772316812591 L70.475,253.5429039544387 L70.79,253.51232450603885 L71.105,253.4854689944615 L71.42,253.4623097430671 L71.735,253.44281588953274 L72.05,253.42695353133806 L72.365,253.41468586745455 L72.68,253.40597333631422 L72.995,253.40077375013118 L73.31,253.39904242564938 L73.625,253.40073231138766 L73.94,253.40579411145274 L74.255,253.41417640598942 L74.57,253.42582576833584 L74.885,253.44068687895066 L75.2,253.4587026361782 L75.515,253.47981426391598 L75.83,253.50396141624816 L76.145,253.53108227910755 L76.46,253.56111366902755 L76.775,253.59399112904418 L77.09,253.62964902180778 L77.405,253.66802061996268 L77.72,253.70903819385185 L78.035,253.75263309660343 L78.35,253.79873584665373 L78.665,253.84727620776187 L78.98,253.89818326656905 L79.295,253.9513855077549 L79.61,254.0068108868431 L79.925,254.0643869007062 L80.24,254.12404065582012 L80.555,254.18569893431695 L80.87,254.24928825788413 L81.185,254.31473494955748 L81.5,254.38196519345428 L81.815,254.4509050924921 L82.13,254.521480724138 L82.445,254.5936181942325 L82.76,254.6672436889308 L83.075,254.74228352480452 L83.39,254.81866419714495 L83.705,254.8963124265092 L84.02,254.97515520354904 L84.335,255.05511983216212 L84.65,255.13613397100445 L84.965,255.21812567340183 L85.28,255.30102342569774 L85.595,255.38475618407443 L85.91,255.46925340988324 L86.225,255.55444510351919 L86.54,255.64026183687486 L86.855,255.7266347844074 L87.17,255.81349575285233 L87.485,255.90077720961645 L87.8,255.9884123098827 L88.115,256.0763349224579 L88.43,256.16447965439477 L88.745,256.25278187441893 L89.06,256.3411777351894 L89.375,256.429604194424 L89.69,256.5179990349162 L90.005,256.6063008834732 L90.32,256.69444922880183 L90.635,256.78238443837034 L90.95,256.8700477742716 L91.265,256.9573814081146 L91.58,257.04432843496977 L91.895,257.13083288639274 L92.21,257.21683974255126 L92 ...

# %% [markdown]
# ## runtests

# %%
# pwd() |> display
# include("./test/runtests.jl")
Pkg.test()
# Out:
#      Testing Antiq
#       Status `C:\Users\user\AppData\Local\Temp\jl_firBPY\Project.toml`
#   [be6e5d0e] Antiq v0.0.16 `C:\Users\user\Desktop\GitHub\Antiq.jl`
#   [b964fa9f] LaTeXStrings v1.3.1
#   [23fbe1c1] Latexify v0.16.1
#   [1fd47b50] QuadGK v2.9.1
#   [276daf66] SpecialFunctions v2.3.1
#   [fd094767] Suppressor v0.2.6
#   [0c5d862f] Symbolics v5.10.0
#   [d6f4376e] Markdown `@stdlib/Markdown`
#   [de0858da] Printf `@stdlib/Printf`
#   [8dfed614] Test `@stdlib/Test`
#       Status `C:\Users\user\AppData\Local\Temp\jl_firBPY\Manifest.toml`
#   [47edcb42] ADTypes v0.2.5
# ⌅ [c3fe647b] AbstractAlgebra v0.32.5
#   [1520ce14] AbstractTrees v0.4.4
#   [79e6a3ab] Adapt v3.7.1
#   [be6e5d0e] Antiq v0.0.16 `C:\Users\user\Desktop\GitHub\Antiq.jl`
# ⌅ [4fba245c] ArrayInterface v7.5.1
#   [e2ed5e7c] Bijections v0.1.6
#   [49dc2e85] Calculus v0.5.1
#   [d360d2e6] ChainRulesCore v1.18.0
#   [9e997f8a] ChangesOfVariables v0.1.8
#   [861a8166] Combinatorics v1.0.2
#   [38540f10] CommonSolve v0.2.4
#   [bbf7d656] CommonSubexpressions v0.3.0
#   [34da2185] Compat v4.10.0
#   [b152e2b5] CompositeTypes v0.1.3
#   [187b0558] ConstructionBase v1.5.4
#   [9a962f9c] DataAPI v1.15.0
#   [864edb3b] DataStructures v0.18.15
#   [e2d170a0] DataValueInterfaces v1.0.0
#   [b429d917] DensityInterface v0.4.0
#   [163ba53b] DiffResults v1.1.0
#   [b552c78f] DiffRules v1.15.1
#   [31c24e10] Distributions v0.25.103
#   [ffbed154] DocStringExtensions v0.9.3
# ⌅ [5b8099bc] DomainSets v0.6.7
#   [fa6b7ba4] DualNumbers v0.6.8
#   [7c1d4256] DynamicPolynomials v0.5.3
#   [4e289a0a] EnumX v1.0.4
#   [e2ba6199] ExprTools v0.1.10
#   [1a297f60] FillArrays v1.8.0
#   [59287772] Formatting v0.4.2
#   [f6369f11] ForwardDiff v0.10.36
#   [069b7b12] FunctionWrappers v1.1.3
#   [77dc65aa] FunctionWrappersWrappers v0.1.3
#   [46192b85] GPUArraysCore v0.1.5
# ⌅ [0b43b601] Groebner v0.4.4
#   [d5909c97] GroupsCore v0.4.0
#   [34004b35] HypergeometricFunctions v0.3.23
#   [615f187c] IfElse v0.1.1
#   [18e54dd8] IntegerMathUtils v0.1.2
#   [8197267c] IntervalSets v0.7.8
#   [3587e190] InverseFunctions v0.1.12
#   [92d709cd] IrrationalConstants v0.2.2
#   [82899510] IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] JLLWrappers v1.5.0
#   [b964fa9f] LaTeXStrings v1.3.1
#   [2ee39098] LabelledArrays v1.14.0
#   [984bce1d] LambertW v0.4.6
#   [23fbe1c1] Latexify v0.16.1
#   [50d2b5c4] Lazy v0.15.1
#   [2ab3a3ac] LogExpFunctions v0.3.26
#   [1914dd2f] MacroTools v0.5.11
#   [e1d29d7a] Missings v1.1.0
#   [102ac46a] MultivariatePolynomials v0.5.3
#   [d8a4904e] MutableArithmetics v1.3.3
#   [77ba4419] NaNMath v1.0.2
#   [bac558e1] OrderedCollections v1.6.3
#   [90014a1f] PDMats v0.11.30
#   [d236fae5] PreallocationTools v0.4.12
#   [aea7be01] PrecompileTools v1.2.0
#   [21216c6a] Preferences v1.4.1
#   [27ebfcd6] Primes v0.5.5
#   [1fd47b50] QuadGK v2.9.1
#   [fb686558] RandomExtensions v0.4.4
#   [3cdcf5f2] RecipesBase v1.3.4
#   [731186ca] RecursiveArrayTools v2.38.10
#   [189a3867] Reexport v1.2.2
#   [ae029012] Requires v1.3.0
#   [79098fc4] Rmath v0.7.1
#   [7e49a35a] RuntimeGeneratedFunctions v0.5.12
#   [fdea26ae] SIMD v3.4.6
# ⌅ [0bca4576] SciMLBase v2.6.0
#   [c0aeaf25] SciMLOperators v0.3.7
#   [efcf1570] Setfield v1.1.1
#   [66db9d55] SnoopPrecompile v1.0.3
#   [a2af1166] SortingAlgorithms v1.2.0
#   [276daf66] SpecialFunctions v2.3.1
#   [90137ffa] StaticArrays v1.7.0
#   [1e83bf80] StaticArraysCore v1.4.2
#   [82ae8749] StatsAPI v1.7.0
#   [2913bbd2] StatsBase v0.34.2
#   [4c63d2b9] StatsFuns v1.3.0
#   [fd094767] Suppressor v0.2.6
#   [2efcf032] SymbolicIndexingInterface v0.2.2
#   [d1185830] SymbolicUtils v1.4.0
#   [0c5d862f] Symbolics v5.10.0
#   [3783bdb8] TableTraits v1.0.1
#   [bd369af6] Tables v1.11.1
#   [a759f4b9] TimerOutputs v0.5.23
#   [a2a6695c] TreeViews v0.3.0
#   [410a4b4d] Tricks v0.1.8
#   [781d530d] TruncatedStacktraces v1.4.0
#   [a7c27f48] Unityper v0.1.5
#   [700de1a5] ZygoteRules v0.2.4
#   [efe28fd5] OpenSpecFun_jll v0.5.5+0
#   [f50d1b31] Rmath_jll v0.4.0+0
#   [0dad84c5] ArgTools v1.1.1 `@stdlib/ArgTools`
#   [56f22d72] Artifacts `@stdlib/Artifacts`
#   [2a0f44e3] Base64 `@stdlib/Base64`
#   [ade2ca70] Dates `@stdlib/Dates`
#   [8ba89e20] Distributed `@stdlib/Distributed`
#   [f43a241f] Downloads v1.6.0 `@stdlib/Downloads`
#   [7b1f6079] FileWatching `@stdlib/FileWatching`
#   [9fa8497b] Future `@stdlib/Future`
#   [b77e0a4c] InteractiveUtils `@stdlib/InteractiveUtils`
#   [b27032c2] LibCURL v0.6.3 `@stdlib/LibCURL`
#   [76f85450] LibGit2 `@stdlib/LibGit2`
#   [8f399da3] Libdl `@stdlib/Libdl`
#   [37e2e46d] LinearAlgebra `@stdlib/LinearAlgebra`
#   [56ddb016] Logging `@stdlib/Logging`
#   [d6f4376e] Markdown `@stdlib/Markdown`
#   [ca575930] NetworkOptions v1.2.0 `@stdlib/NetworkOptions`
#   [44cfe95a] Pkg v1.8.0 `@stdlib/Pkg`
#   [de0858da] Printf `@stdlib/Printf`
#   [3fa0cd96] REPL `@stdlib/REPL`
#   [9a3f8284] Random `@stdlib/Random`
#   [ea8e919c] SHA v0.7.0 `@stdlib/SHA`
#   [9e88b42a] Serialization `@stdlib/Serialization`
#   [6462fe0b] Sockets `@stdlib/Sockets`
#   [2f01184e] SparseArrays `@stdlib/SparseArrays`
#   [10745b16] Statistics `@stdlib/Statistics`
#   [4607b0f0] SuiteSparse `@stdlib/SuiteSparse`
#   [fa267f1f] TOML v1.0.0 `@stdlib/TOML`
#   [a4e569a6] Tar v1.10.1 `@stdlib/Tar`
#   [8dfed614] Test `@stdlib/Test`
#   [cf7118a7] UUIDs `@stdlib/UUIDs`
#   [4ec0a83e] Unicode `@stdlib/Unicode`
#   [e66e0078] CompilerSupportLibraries_jll v0.5.2+0 `@stdlib/CompilerSupportLibraries_jll`
#   [deac9b47] LibCURL_jll v7.84.0+0 `@stdlib/LibCURL_jll`
#   [29816b5a] LibSSH2_jll v1.10.2+0 `@stdlib/LibSSH2_jll`
#   [c8ffd9c3] MbedTLS_jll v2.28.0+0 `@stdlib/MbedTLS_jll`
#   [14a3606d] MozillaCACerts_jll v2022.2.1 `@stdlib/MozillaCACerts_jll`
#   [4536629a] OpenBLAS_jll v0.3.20+0 `@stdlib/OpenBLAS_jll`
#   [05823500] OpenLibm_jll v0.8.1+0 `@stdlib/OpenLibm_jll`
#   [83775a58] Zlib_jll v1.2.12+3 `@stdlib/Zlib_jll`
#   [8e850b90] libblastrampoline_jll v5.1.1+0 `@stdlib/libblastrampoline_jll`
#   [8e850ede] nghttp2_jll v1.48.0+0 `@stdlib/nghttp2_jll`
#   [3f19e933] p7zip_jll v17.4.0+0 `@stdlib/p7zip_jll`
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading.
#      Testing Running tests...
# WARNING: replacing module MorsePotential1669411154543485985.
# Test Summary: | Pass  Total     Time
# Antiq.jl      | 2052   2052  1m20.7s
#      Testing Antiq tests passed

# %% [markdown]
# ## Weave.jl

# %%
run(`julia --project=docs/ -e 'using Pkg; Pkg.activate("./"); cd("docs"); include("jmd2md.jl")'`)
# Out:
# The latest version of Julia in the `release` channel is 1.9.4+0.x64.w64.mingw32. You currently have `1.9.2+0.x64.w64.mingw32` installed. Run:
#
#   juliaup update
#
# to install Julia 1.9.4+0.x64.w64.mingw32 and update the `release` channel to that version.
#   Activating project at `C:\Users\user\Desktop\GitHub\Antiq.jl`
# ┌ Info: Weaving chunk 1 from line 55
# └   progress = 0.0
# ┌ Info: Weaving chunk 2 from line 62
# └   progress = 0.16666666666666666
# ┌ Info: Weaving chunk 3 from line 70
# └   progress = 0.3333333333333333
# ┌ Info: Weaving chunk 4 from line 77
# └   progress = 0.5
# ┌ Info: Weaving chunk 5 from line 89
# └   progress = 0.6666666666666666
# ┌ Info: Weaving chunk 6 from line 107
# └   progress = 0.8333333333333334
# WARNING: replacing module InfinitePotentialWell8472295553246349096.
# ┌ Info: Weaved all chunks
# └   progress = 1
# [ Info: Weaved to C:\Users\user\Desktop\GitHub\Antiq.jl\docs\src\InfinitePotentialWell.md
# m.match = ".jl\")\n```\n\n```"
# m.offset = 3032
# m.match = "```\n```\n\n\n"
# m.offset = 25373
# ┌ Info: Weaving chunk 1 from line 93
# └   progress = 0.0
# ┌ Info: Weaving chunk 2 from line 100
# └   progress = 0.14285714285714285
# ┌ Info: Weaving chunk 3 from line 108
# └   progress = 0.2857142857142857
# ┌ Info: Weaving chunk 4 from line 115
# └   progress = 0.42857142857142855
# ┌ Info: Weaving chunk 5 from line 122
# └   progress = 0.5714285714285714
# ┌ Info: Weaving chunk 6 from line 134
# └   progress = 0.7142857142857143
# ┌ Info: Weaving chunk 7 from line 152
# └   progress = 0.8571428571428571
# WARNING: replacing module HarmonicOscillator3094684212771689889.
# ┌ Warning: ERROR: LoadError occurred, including output in Weaved document
# └ @ Weave C:\Users\user\.julia\packages\Weave\f7Ly3\src\run.jl:224
# ┌ Info: Weaved all chunks
# └   progress = 1
# [ Info: Weaved to C:\Users\user\Desktop\GitHub\Antiq.jl\docs\src\HarmonicOscillator.md
# m.match = ".jl\")\n```\n\n```"
# m.offset = 6290
# ┌ Info: Weaving chunk 1 from line 85
# └   progress = 0.0
# ┌ Info: Weaving chunk 2 from line 92
# └   progress = 0.14285714285714285
# ┌ Info: Weaving chunk 3 from line 102
# └   progress = 0.2857142857142857
# ┌ Info: Weaving chunk 4 from line 109
# └   progress = 0.42857142857142855
# ┌ Info: Weaving chunk 5 from line 116
# └   progress = 0.5714285714285714
# ┌ Info: Weaving chunk 6 from line 129
# └   progress = 0.7142857142857143
# WARNING: replacing module MorsePotential1669411154543485985.
# ┌ Info: Weaving chunk 7 from line 152
# └   progress = 0.8571428571428571
# WARNING: replacing module MorsePotential1669411154543485985.
# ┌ Warning: ERROR: LoadError occurred, including output in Weaved document
# └ @ Weave C:\Users\user\.julia\packages\Weave\f7Ly3\src\run.jl:224
# ┌ Info: Weaved all chunks
# └   progress = 1
# [ Info: Weaved to C:\Users\user\Desktop\GitHub\Antiq.jl\docs\src\MorsePotential.md
# m.match = ".jl\")\n```\n\n```"
# m.offset = 5890
# ┌ Info: Weaving chunk 1 from line 156
# └   progress = 0.0
# ┌ Info: Weaving chunk 2 from line 163
# └   progress = 0.1111111111111111
# ┌ Info: Weaving chunk 3 from line 173
# └   progress = 0.2222222222222222
# ┌ Info: Weaving chunk 4 from line 180
# └   progress = 0.3333333333333333
# ┌ Info: Weaving chunk 5 from line 188
# └   progress = 0.4444444444444444
# ┌ Info: Weaving chunk 6 from line 213
# └   progress = 0.5555555555555556
# ┌ Info: Weaving chunk 7 from line 221
# └   progress = 0.6666666666666666
# ┌ Info: Weaving chunk 8 from line 232
# └   progress = 0.7777777777777778
# ┌ Info: Weaving chunk 9 from line 247
# └   progress = 0.8888888888888888
# WARNING: replacing module HydrogenAtom11641542298082958385.
# WARNING: replacing module MorsePotential1669411154543485985.
# m.match = ".jl\")\n```\n\n```"
# m.offset = 13672
# m.match = "```\n```\n\n\n"
# m.offset = 104714
# ┌ Info: Weaved all chunks
# └   progress = 1
# [ Info: Weaved to C:\Users\user\Desktop\GitHub\Antiq.jl\docs\src\HydrogenAtom.md
# Process(`julia --project=docs/ -e 'using Pkg; Pkg.activate("./"); cd("docs"); include("jmd2md.jl")'`, ProcessExited(0))

# %% [markdown]
# ## Documenter.jl

# %%
# run(`cmd /C cd \& julia ./docs/make.jl`)
# include("./docs/make.jl")
run(`julia --project=docs/ -e 'using Pkg; Pkg.activate("./"); cd("docs"); include("make.jl")'`)
# Out:
# The latest version of Julia in the `release` channel is 1.9.4+0.x64.w64.mingw32. You currently have `1.9.2+0.x64.w64.mingw32` installed. Run:
#
#   juliaup update
#
# to install Julia 1.9.4+0.x64.w64.mingw32 and update the `release` channel to that version.
#   Activating project at `C:\Users\user\Desktop\GitHub\Antiq.jl`
# [ Info: SetupBuildDirectory: setting up build directory.
# [ Info: Doctest: running doctests.
# [ Info: ExpandTemplates: expanding markdown templates.
# ┌ Warning: In src\HarmonicOscillator.md:1-3: `@meta` block has an unsupported keyword argument: CurrentModule
# └ @ Documenter C:\Users\user\.julia\packages\Documenter\ifiMq\src\expander_pipeline.jl:298
# ┌ Warning: In src\HydrogenAtom.md:1-3: `@meta` block has an unsupported keyword argument: CurrentModule
# └ @ Documenter C:\Users\user\.julia\packages\Documenter\ifiMq\src\expander_pipeline.jl:298
# ┌ Warning: In src\InfinitePotentialWell.md:1-3: `@meta` block has an unsupported keyword argument: CurrentModule
# └ @ Documenter C:\Users\user\.julia\packages\Documenter\ifiMq\src\expander_pipeline.jl:298
# ┌ Warning: In src\MorsePotential.md:1-3: `@meta` block has an unsupported keyword argument: CurrentModule
# └ @ Documenter C:\Users\user\.julia\packages\Documenter\ifiMq\src\expander_pipeline.jl:298
# ┌ Warning: In src\index.md:1-3: `@meta` block has an unsupported keyword argument: CurrentModule
# └ @ Documenter C:\Users\user\.julia\packages\Documenter\ifiMq\src\expander_pipeline.jl:298
# [ Info: CrossReferences: building cross-references.
# [ Info: CheckDocument: running document checks.
# [ Info: Populate: populating indices.
# [ Info: RenderDocument: rendering document.
# [ Info: HTMLWriter: rendering HTML pages.
# ┌ Warning: Unable to determine the repository root URL for the navbar link.
# │ This can happen when a string is passed to the `repo` keyword of `makedocs`.
# │
# │ To remove this warning, either pass a Remotes.Remote object to `repo` to completely
# │ specify the remote repository, or explicitly set the remote URL by setting `repolink`
# │ via `makedocs(format = HTML(repolink = "..."), ...)`.
# └ @ Documenter.HTMLWriter C:\Users\user\.julia\packages\Documenter\ifiMq\src\html\HTMLWriter.jl:707
# ┌ Warning: Generated HTML over size_threshold_warn limit: HydrogenAtom.md
# │     Generated file size: 118.26 (KiB)
# │     size_threshold_warn: 100.0 (KiB)
# │     size_threshold:      200.0 (KiB)
# │     HTML file:           HydrogenAtom.html
# └ @ Documenter.HTMLWriter C:\Users\user\.julia\packages\Documenter\ifiMq\src\html\HTMLWriter.jl:1793
# ┌ Warning: Documenter could not auto-detect the building environment Skipping deployment.
# └ @ Documenter C:\Users\user\.julia\packages\Documenter\ifiMq\src\deployconfig.jl:76
# Process(`julia --project=docs/ -e 'using Pkg; Pkg.activate("./"); cd("docs"); include("make.jl")'`, ProcessExited(0))
